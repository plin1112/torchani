# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

lines = np.loadtxt("comparison_cm5_calculated_vs_predicted.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

plt.figure(0)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -0.9, stop = 0.5, num = 141)
plt.figure(0)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.005037551312052009

# %%
lines = np.loadtxt("comparison_cm5_gdb11_07_test500_mod.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

# plt.clf()
plt.figure(1)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_cm5_gdb11_08_test500_mod.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

# plt.clf()
plt.figure(2)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_cm5_gdb11_09_test500_mod.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

# plt.clf()
plt.figure(3)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_cm5_gdb11_10_test500_mod.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

# plt.clf()
plt.figure(4)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_cm5_gdb11_11_test500_mod.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

# plt.clf()
plt.figure(5)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_cm5_gdb13_12_test1000_mod.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

# plt.clf()
plt.figure(6)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_cm5_gdb13_13_test1000_mod.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

# plt.clf()
plt.figure(8)
plt.clf()
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
type(x)
# Out:
# numpy.ndarray

# %%
A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -0.9, stop = 0.5, num = 141)
plt.figure(7)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
plt.legend()
plt.show()
# Out:
# RMSE = 0.013697698927574952
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

lines = np.loadtxt("comparison_dipolecharges_drugbank_testset_mod.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[0:1000, 0]
y = lines[0:1000, 1]

fig_no = 8
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -0.9, stop = 0.5, num = 141)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.012495904297233447

# %%
lines = np.loadtxt("comparison_charges_drugbank_testset_mod2.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[0:10000, 0]
y = lines[0:10000, 1]

fig_no = 9
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.010212093704444236

# %%
lines = np.loadtxt("comparison_dipoles_drugbank_testset_mod2.txt", dtype=np.float64, usecols=(0, 1, 2, 3), unpack=False)
x = lines[:, 0]
y = lines[:, 1]
x2 = lines[:, 2]
y2 = lines[:, 3]


fig_no = 10
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x02 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x02, m*x02 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
plt.legend()
plt.show()

fig_no = 11
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

# plt.plot(x, y, 'o', label='Original data', markersize=10)
plt.figure(fig_no)
plt.scatter(x2, y2, edgecolors='none', s=4, alpha=0.5)
# plt.plot(x22, m*x22 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
# plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.028697389722213463
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_dipoles_drugbank_testset_mod3.txt", dtype=np.float64, usecols=(0, 1, 2, 3), unpack=False)
x = lines[:, 0]
y = lines[:, 1]
x2 = lines[:, 2]
y2 = lines[:, 3]


fig_no = 12
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x02 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x02, m*x02 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
plt.legend()
plt.show()

fig_no = 13
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

# plt.plot(x, y, 'o', label='Original data', markersize=10)
plt.figure(fig_no)
plt.scatter(x2, y2, edgecolors='none', s=4, alpha=0.5)
# plt.plot(x22, m*x22 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
# plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.028605969983902253
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_charges_drugbank_testset_mod3.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[0:10000, 0]
y = lines[0:10000, 1]

fig_no = 14
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.01649046477385427

# %%
lines = np.loadtxt("comparison_charges_drugbank_testset_mod5.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[0:10000, 0]
y = lines[0:10000, 1]

fig_no = 15
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.08087610321142437

# %%
lines = np.loadtxt("comparison_dipoles_drugbank_testset_mod5.txt", dtype=np.float64, usecols=(0, 1, 2, 3), unpack=False)
x = lines[:, 0]
y = lines[:, 1]
x2 = lines[:, 2]
y2 = lines[:, 3]


fig_no = 16
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x02 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x02, m*x02 + c, 'r', label=('Fitted line, y = %8.4f x + %8.4f, R^2 = %s' % (m, c, r2)))
plt.legend()
plt.show()

fig_no = 17
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

# plt.plot(x, y, 'o', label='Original data', markersize=10)
plt.figure(fig_no)
plt.scatter(x2, y2, edgecolors='none', s=4, alpha=0.5)
# plt.plot(x22, m*x22 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
# plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.029245580473222843
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_dipoles_drugbank_testset_mod5-1.txt", dtype=np.float64, usecols=(0, 1, 2, 3), unpack=False)
x = lines[:, 0]
y = lines[:, 1]
x2 = lines[:, 2]
y2 = lines[:, 3]


fig_no = 18
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x02 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x02, m*x02 + c, 'r', label=('Fitted line, y = %8.4f x + %8.4f, R^2 = %s' % (m, c, r2)))
plt.legend()
plt.show()

fig_no = 19
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

# plt.plot(x, y, 'o', label='Original data', markersize=10)
plt.figure(fig_no)
plt.scatter(x2, y2, edgecolors='none', s=4, alpha=0.5)
# plt.plot(x22, m*x22 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
# plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.029033452319952045
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("comparison_charges_drugbank_testset_mod5.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

fig_no = 20
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, y = %8.5f x + %8.5f, R^2 = %s' % (m, c, r2)))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.08105852239918417

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

lines = np.loadtxt("./comparison_charges_ani_al_901_training_1.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

fig_no = 21
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, y = %8.5f x + %8.5f, R^2 = %s' % (m, c, r2)))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.08110637148386798

# %%
lines = np.loadtxt("./comparison_dipoles_ani_al_901_training_1.txt", dtype=np.float64, usecols=(0, 1, 2, 3), unpack=False)
x = lines[:, 0]
y = lines[:, 1]
x2 = lines[:, 2]
y2 = lines[:, 3]


fig_no = 22
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x02 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x02, m*x02 + c, 'r', label=('Fitted line, y = %8.4f x + %8.4f, R^2 = %s' % (m, c, r2)))
plt.legend()
plt.show()

fig_no += 1
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

# plt.plot(x, y, 'o', label='Original data', markersize=10)
plt.figure(fig_no)
plt.scatter(x2, y2, edgecolors='none', s=4, alpha=0.5)
# plt.plot(x22, m*x22 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
# plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.02355070401557338
# <img src="data:image/png;base64,..." width="640">

# %%
lines = np.loadtxt("./comparison_charges_ani_al_901_validation_1.txt", dtype=np.float64, usecols=(1,2), unpack=False)
x = lines[:, 0]
y = lines[:, 1]

fig_no = 24
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x2 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x2, m*x2 + c, 'r', label=('Fitted line, y = %8.5f x + %8.5f, R^2 = %s' % (m, c, r2)))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.07382517563906035

# %%
lines = np.loadtxt("./comparison_dipoles_ani_al_901_validation_1.txt", dtype=np.float64, usecols=(0, 1, 2, 3), unpack=False)
x = lines[:, 0]
y = lines[:, 1]
x2 = lines[:, 2]
y2 = lines[:, 3]


fig_no = 25
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

A = np.vstack([x, np.ones(len(x))]).T
model, resid = np.linalg.lstsq(A, y, rcond=None)[:2]
m, c = model
r2 = 1 - resid / (y.size * y.var())
rmse = np.linalg.norm(m*x + c - y) / np.sqrt(len(x))
print('RMSE =', rmse)
# plt.plot(x, y, 'o', label='Original data', markersize=10)
x02 = np.linspace(start = -1.0, stop = 1.0, num = 201)
plt.figure(fig_no)
plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
plt.plot(x02, m*x02 + c, 'r', label=('Fitted line, y = %8.4f x + %8.4f, R^2 = %s' % (m, c, r2)))
plt.legend()
plt.show()

fig_no += 1
plt.figure(fig_no)
plt.clf()
# plt.scatter(x, y, edgecolors='none', s=4, alpha=0.5)
# plt.show()

# plt.plot(x, y, 'o', label='Original data', markersize=10)
plt.figure(fig_no)
plt.scatter(x2, y2, edgecolors='none', s=4, alpha=0.5)
# plt.plot(x22, m*x22 + c, 'r', label=('Fitted line, R^2 = %s' % r2))
# plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# RMSE = 0.03362433321620703
# <img src="data:image/png;base64,..." width="640">
