# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
import numpy as np

# %matplotlib inline

# %%
fig = plt.figure()

x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)
plt.colorbar()

# %%
fig = plt.figure()

def f(x, y, Rc):
    r_ij = np.sqrt((x**2 + y**2))
    r_ij[r_ij > Rc] = Rc
    ret = 0.5 + 0.5 * np.cos(np.pi * r_ij / Rc)
    return ret
    
x = np.linspace(-8.0, 8.0, 1000)
y = np.linspace(-8.0, 8.0, 1000)

X, Y = np.meshgrid(x, y)

# contours = plt.contour(X, Y, Z, 3, colors='black')
# plt.clabel(contours, inline=True, fontsize=8)

# plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
#            cmap='RdGy', alpha=0.5)
# plt.colorbar();

for Rc in [5.2]:
    # fc = 0.5 + 0.5 * np.cos(np.pi * np.sqrt((X**2 + Y**2)) / Rc)
    Z = f(X, Y, Rc)
    # plt.contourf(X, Y, Z, 20, cmap='RdGy')
    plt.imshow(Z, extent=[-8, 8, -8, 8], alpha=1.0, origin='lower')
    # plt.imshow(Z)

plt.colorbar()

# %%
fig = plt.figure()

def f(x, y, Rc):
    r_ij = np.sqrt((x**2 + y**2))
    r_ij[r_ij > Rc] = Rc
    ret = 0.5 + 0.5 * np.cos(np.pi * r_ij / Rc)
    return ret

def g(x, y, Rs, Rc):
    r_ij = np.sqrt((x**2 + y**2))
    r_ij[r_ij > Rc] = Rc
    ret = np.exp(-16.0 * (r_ij - Rs)**2) * (0.5 + 0.5 * np.cos(np.pi * r_ij / Rc))
    return ret
    
x = np.linspace(-8.0, 8.0, 1000)
y = np.linspace(-8.0, 8.0, 1000)

X, Y = np.meshgrid(x, y)

# contours = plt.contour(X, Y, Z, 3, colors='black')
# plt.clabel(contours, inline=True, fontsize=8)

# plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
#            cmap='RdGy', alpha=0.5)
# plt.colorbar();
Rc = 5.2
for Rs in [0.5, 1.17, 1.83, 2.50, 3.17, 3.83, 4.50, 5.17]:
    # fc = 0.5 + 0.5 * np.cos(np.pi * np.sqrt((X**2 + Y**2)) / Rc)
    Z = g(X, Y, Rs, Rc)
    # plt.contourf(X, Y, Z, 20, cmap='RdGy')
    plt.imshow(Z, extent=[-8, 8, -8, 8], alpha=0.1, cmap='Blues', origin='lower')
    # plt.imshow(Z)

plt.colorbar()

# %%
fig = plt.figure()

def f(x, y, Rc):
    r_ij = np.sqrt((x**2 + y**2))
    r_ij[r_ij > Rc] = Rc
    ret = 0.5 + 0.5 * np.cos(np.pi * r_ij / Rc)
    return ret

def g(x, y, Rs, Rc):
    r_ij = np.sqrt((x**2 + y**2))
    r_ij[r_ij > Rc] = Rc
    ret = np.exp(-8.0 * ((1.0 + r_ij) / 2.0 - Rs)**2) * (0.5 + 0.5 * np.cos(np.pi * r_ij / Rc)) * (1 + cos())
    return ret

def a(x, y, Rs, Rc):
    # R(i) = (0, 1)
    r_ij = np.sqrt((x**2 + y**2))
    r_ij[r_ij > Rc] = Rc
    ret = np.exp(-16.0 * (r_ij - Rs)**2) * (0.5 + 0.5 * np.cos(np.pi * r_ij / Rc))
    return ret

x = np.linspace(-8.0, 8.0, 1000)
y = np.linspace(-8.0, 8.0, 1000)

X, Y = np.meshgrid(x, y)

# contours = plt.contour(X, Y, Z, 3, colors='black')
# plt.clabel(contours, inline=True, fontsize=8)

# plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
#            cmap='RdGy', alpha=0.5)
# plt.colorbar();
Rc = 3.2
for Rs in [0.196, 0.589, 0.982, 1.374, 1.767, 2.160, 2.553, 2.945]:
    # fc = 0.5 + 0.5 * np.cos(np.pi * np.sqrt((X**2 + Y**2)) / Rc)
    a = g(X, Y, Rs, Rc)
    # plt.contourf(X, Y, Z, 20, cmap='RdGy')
    plt.imshow(Z, extent=[-8, 8, -8, 8], alpha=0.1, cmap='Blues', origin='lower')
    # plt.imshow(Z)

plt.colorbar()

# %%
from mpl_toolkits.mplot3d import Axes3D 

x = np.linspace(-8.0, 8.0, 1000)
y = np.linspace(-8.0, 8.0, 1000)

X, Y = np.meshgrid(x, y)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface.
for Rc in [0.5]: # , 1.17, 1.83, 2.50, 3.17, 3.83, 4.50, 5.17]:
    # fc = 0.5 + 0.5 * np.cos(np.pi * np.sqrt((X**2 + Y**2)) / Rc)
    Z = f(X, Y, Rc)
    ax.plot_surface(X, Y, Z) # , cmap=plt.cm.YlGnBu_r)

# Tweak the limits and add latex math labels.
ax.set_zlim(0, 1)
ax.set_xlabel(r'$\phi_\mathrm{real}$')
ax.set_ylabel(r'$\phi_\mathrm{im}$')
ax.set_zlabel(r'$V(\phi)$')

plt.show()
